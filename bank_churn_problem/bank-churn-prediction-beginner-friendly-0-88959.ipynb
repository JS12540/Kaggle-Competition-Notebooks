# %% [markdown]
# ## **What I improved**
#
# * **Added the surnames to training and testing (looks stupid but somehow it affects the churn probability**
#
# * **To add the surnames I have to vectorize it to become in a numerical format, I used TF-IDF vectorizer, I can explain it if you need, just drop a comment.**
#
# * **For the TF-IDF it return a lot of features which is too much for the memory, so we use PCA for dimensionality reduction, I chose here to take only the first 10 components**
#
# * **Introducing new features, the features are created by the incredible notebook (https://www.kaggle.com/code/chinmayadatt/notebook-analysing-bank-churn-dataset), make sure to check it out and vote if you find it helpful. I will make my own feature engineering later when I find sometime.**

# %% [markdown]
# # **Importing libraries and files**

# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, RepeatedStratifiedKFold


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s4e1/sample_submission.csv
# /kaggle/input/playground-series-s4e1/train.csv
# /kaggle/input/playground-series-s4e1/test.csv
# /kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv
# /kaggle/input/bank-customer-churn-dataset/Bank Customer Churn Prediction.csv

# %% [markdown]
# # **1. Import data**

# %%
df_train = pd.read_csv("/kaggle/input/playground-series-s4e1/train.csv")
original_data = pd.read_csv("/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv")
df_test = pd.read_csv("/kaggle/input/playground-series-s4e1/test.csv")
submission = pd.read_csv("/kaggle/input/playground-series-s4e1/sample_submission.csv")

# %% [markdown]
# # **2. Exploratory Data Analysis (EDA)**

# %%
df_train.shape
# Out:
# (165034, 14)

# %%
df_train.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
original_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1        1.0             1.0
# 1       1   83807.86              1        0.0             1.0
# 2       8  159660.80              3        1.0             0.0
# 3       1       0.00              2        0.0             0.0
# 4       2  125510.82              1        NaN             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df_test.head()
# Out:
#        id  CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0  165034    15773898   Lucchese          586    France  Female  23.0       2
# 1  165035    15782418       Nott          683    France  Female  46.0       2
# 2  165036    15807120         K?          656    France  Female  34.0       7
# 3  165037    15808905  O'Donnell          681    France    Male  36.0       8
# 4  165038    15607314    Higgins          752   Germany    Male  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00

# %%
submission.head()
# Out:
#        id  Exited
# 0  165034     0.5
# 1  165035     0.5
# 2  165036     0.5
# 3  165037     0.5
# 4  165038     0.5

# %%
df_train.isna().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
original_data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          1
# Gender             0
# Age                1
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          1
# IsActiveMember     1
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
original_data.duplicated().sum()
# Out:
# 2

# %%
df_train = df_train.drop("id", axis=1)
original_data = original_data.drop("RowNumber", axis=1)

# %%
original_data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    France  Female  42.0       8
# 3    15701354      Boni          699    France  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1        1.0             1.0        101348.88
# 1   83807.86              1        0.0             1.0        112542.58
# 2  159660.80              3        1.0             0.0        113931.57
# 3       0.00              2        0.0             0.0         93826.63
# 4  125510.82              1        NaN             1.0         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df_train = pd.concat([df_train, original_data], axis=0)

# %%
df_train.shape
# Out:
# (175036, 13)

# %%
df_train.duplicated().sum()
# Out:
# 2

# %%
df_train.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          1
# Gender             0
# Age                1
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          1
# IsActiveMember     1
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ***
# ## **We can see that we have some rows that are duplicated and we have some rows that have missing values**
#
# ## **For the duplicated rows we will drop them to keep them unique, and for the missing values we could impute them but as we can see it's a negligibale amount so we can drop them as well**
# ***

# %%
df_train = df_train.drop_duplicates()

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train = df_train.dropna()

# %%
df_train.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## **Here we will do some TF-IDF vectorization for the surnames**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import gc


# we return same text, because here we dont do any tokenization because surnames are usually not sentences and regular english language
def dummy(text):
    return text

vectorizer = TfidfVectorizer(ngram_range=(3, 5), lowercase=False, sublinear_tf=True, analyzer = 'word',
    tokenizer = dummy,
    preprocessor = dummy,
    token_pattern = None, 
    strip_accents='unicode',
    max_features=1000
)

vectorizer.fit(df_train["Surname"])

vocab = vectorizer.vocabulary_

vectorizer = TfidfVectorizer(ngram_range=(3, 5), lowercase=False, sublinear_tf=True, vocabulary=vocab,
                            analyzer = 'word',
                            tokenizer = dummy,
                            preprocessor = dummy,
                            token_pattern = None, strip_accents='unicode', max_features=1000
                            )



train_surnames = vectorizer.fit_transform(df_train["Surname"])
test_surnames = vectorizer.transform(df_test["Surname"])

# we free the space by removing reference to the object vectorizer and use garbage collector
# to remove the unused space from the memory
del vectorizer
gc.collect()
# Out:
# 0

# %% [markdown]
# ### **The TF-IDF will return a huge amount of values, so we do PCA to reduce the space to 10 only**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
tfidf_train_pca = pca.fit_transform(train_surnames.toarray())
tfidf_test_pca = pca.transform(test_surnames.toarray())

pca_columns = [f'Surname_PCA_{i+1}' for i in range(10)]
df_train_pca = pd.DataFrame(tfidf_train_pca, columns=pca_columns)
df_test_pca = pd.DataFrame(tfidf_test_pca, columns=pca_columns)

# %%
df_train_pca.shape
# Out:
# (175030, 10)

# %%
df_train.shape
# Out:
# (175030, 13)

# %%
df_train.reset_index(drop=True, inplace=True)
df_train_pca.reset_index(drop=True, inplace=True)

df_train = pd.concat([df_train, df_train_pca], axis="columns")

# %%
df_train.head()
# Out:
#    CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2    15694510           Hsueh          678    France   Male  40.0      10
# 3    15741417             Kao          581    France   Male  34.0       2
# 4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  ...  Surname_PCA_1  Surname_PCA_2  \
# 0       0.00              2        1.0  ...       0.428586       0.055080
# 1       0.00              2        1.0  ...       0.105779       0.001855
# 2       0.00              2        1.0  ...      -0.035401      -0.029099
# 3  148882.54              1        1.0  ...      -0.035992      -0.029410
# 4       0.00              2        1.0  ...      -0.028723      -0.032024
#
#    Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  Surname_PCA_7  \
# 0       0.043749       0.003175       0.004882       0.005035       0.017626
# 1      -0.007653      -0.004979      -0.016212      -0.029939       0.052591
# 2      -0.037264       0.004022      -0.051364      -0.060943      -0.041192
# 3      -0.042073      -0.011395      -0.042140      -0.056974      -0.026287
# 4      -0.026693      -0.016294      -0.037567      -0.046233      -0.046991
#
#    Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.007490       0.011937        0.009756
# 1       0.027870       0.013041        0.005447
# 2      -0.099771      -0.098887        0.025862
# 3      -0.114804      -0.092143        0.159736
# 4      -0.056859      -0.100200       -0.182821
#
# [5 rows x 23 columns]

# %%
df_test.reset_index(drop=True, inplace=True)
df_test_pca.reset_index(drop=True, inplace=True)

df_test = pd.concat([df_test, df_test_pca], axis="columns")

# %%
df_train = df_train.drop("Surname", axis=1)
df_test  = df_test.drop("Surname", axis=1)

# %%
df_train.head()
# Out:
#    CustomerId  CreditScore Geography Gender   Age  Tenure    Balance  \
# 0    15674932          668    France   Male  33.0       3       0.00
# 1    15749177          627    France   Male  33.0       1       0.00
# 2    15694510          678    France   Male  40.0      10       0.00
# 3    15741417          581    France   Male  34.0       2  148882.54
# 4    15766172          716     Spain   Male  33.0       5       0.00
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_1  \
# 0              2        1.0             0.0  ...       0.428586
# 1              2        1.0             1.0  ...       0.105779
# 2              2        1.0             0.0  ...      -0.035401
# 3              1        1.0             1.0  ...      -0.035992
# 4              2        1.0             1.0  ...      -0.028723
#
#    Surname_PCA_2  Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  \
# 0       0.055080       0.043749       0.003175       0.004882       0.005035
# 1       0.001855      -0.007653      -0.004979      -0.016212      -0.029939
# 2      -0.029099      -0.037264       0.004022      -0.051364      -0.060943
# 3      -0.029410      -0.042073      -0.011395      -0.042140      -0.056974
# 4      -0.032024      -0.026693      -0.016294      -0.037567      -0.046233
#
#    Surname_PCA_7  Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.017626       0.007490       0.011937        0.009756
# 1       0.052591       0.027870       0.013041        0.005447
# 2      -0.041192      -0.099771      -0.098887        0.025862
# 3      -0.026287      -0.114804      -0.092143        0.159736
# 4      -0.046991      -0.056859      -0.100200       -0.182821
#
# [5 rows x 22 columns]

# %% [markdown]
# ## **We get the numerical and categorical columns**

# %%
numeric_data = df_train.select_dtypes(include=[np.number])
categorical_data = df_train.select_dtypes(exclude=[np.number])

# %%
numeric_data.head()
# Out:
#    CustomerId  CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    15674932          668  33.0       3       0.00              2        1.0
# 1    15749177          627  33.0       1       0.00              2        1.0
# 2    15694510          678  40.0      10       0.00              2        1.0
# 3    15741417          581  34.0       2  148882.54              1        1.0
# 4    15766172          716  33.0       5       0.00              2        1.0
#
#    IsActiveMember  EstimatedSalary  Exited  Surname_PCA_1  Surname_PCA_2  \
# 0             0.0        181449.97       0       0.428586       0.055080
# 1             1.0         49503.50       0       0.105779       0.001855
# 2             0.0        184866.69       0      -0.035401      -0.029099
# 3             1.0         84560.88       0      -0.035992      -0.029410
# 4             1.0         15068.83       0      -0.028723      -0.032024
#
#    Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  Surname_PCA_7  \
# 0       0.043749       0.003175       0.004882       0.005035       0.017626
# 1      -0.007653      -0.004979      -0.016212      -0.029939       0.052591
# 2      -0.037264       0.004022      -0.051364      -0.060943      -0.041192
# 3      -0.042073      -0.011395      -0.042140      -0.056974      -0.026287
# 4      -0.026693      -0.016294      -0.037567      -0.046233      -0.046991
#
#    Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.007490       0.011937        0.009756
# 1       0.027870       0.013041        0.005447
# 2      -0.099771      -0.098887        0.025862
# 3      -0.114804      -0.092143        0.159736
# 4      -0.056859      -0.100200       -0.182821

# %%
categorical_data.head()
# Out:
#   Geography Gender
# 0    France   Male
# 1    France   Male
# 2    France   Male
# 3    France   Male
# 4     Spain   Male

# %% [markdown]
# ### The surname is not really a categorical data, also it's really not important to our model so we will drop it

# %%
# categorical_data = categorical_data.drop("Surname", axis=1)
categorical_data.head()
# Out:
#   Geography Gender
# 0    France   Male
# 1    France   Male
# 2    France   Male
# 3    France   Male
# 4     Spain   Male

# %%
corr = numeric_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_985e5_row0_col0, #T_985e5_row1_col1, #T_985e5_row2_col2, #T_985e5_row3_col3, #T_985e5_row4_col4, #T_985e5_row5_col5, #T_985e5_row6_col6, #T_985e5_row7_col7, #T_985e5_row8_col8, #T_985e5_row9_col9, #T_985e5_row10_col10, #T_985e5_row11_col11, #T_985e5_row12_col12, #T_985e5_row13_col13, #T_985e5_row14_col14, #T_985e5_row15_col15, #T_985e5_row16_col16, #T_985e5_row17_col17, #T_985e5_row18_col18, #T_985e5_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col1, #T_985e5_row1_col13, #T_985e5_row4_col1, #T_985e5_row6_col14, #T_985e5_row7_col10, #T_985e5_row7_col13, #T_985e5_row9_col8, #T_985e5_row9_col13, #T_985e5_row12_col6, #T_985e5_row19_col1, #T_985e5_row19_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col2, #T_985e5_row5_col16, #T_985e5_row10_col2, #T_985e5_row13_col2, #T_985e5_row18_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col3, #T_985e5_row0_col8, #T_985e5_row0_col10, #T_985e5_row1_col0, #T_985e5_row1_col6, #T_985e5_row2_col1, #T_985e5_row2_col11, #T_985e5_row2_col14, #T_985e5_row3_col14, #T_985e5_row4_col8, #T_985e5_row5_col11, #T_985e5_row6_col8, #T_985e5_row6_col11, #T_985e5_row7_col11, #T_985e5_row7_col14, #T_985e5_row8_col12, #T_985e5_row8_col14, #T_985e5_row9_col18, #T_985e5_row10_col8, #T_985e5_row10_col11, #T_985e5_row10_col14, #T_985e5_row11_col1, #T_985e5_row11_col8, #T_985e5_row11_col14, #T_985e5_row12_col3, #T_985e5_row12_col11, #T_985e5_row12_col14, #T_985e5_row13_col8, #T_985e5_row13_col11, #T_985e5_row13_col14, #T_985e5_row14_col3, #T_985e5_row14_col11, #T_985e5_row15_col11, #T_985e5_row15_col14, #T_985e5_row16_col3, #T_985e5_row16_col6, #T_985e5_row16_col11, #T_985e5_row16_col14, #T_985e5_row17_col11, #T_985e5_row17_col14, #T_985e5_row18_col8, #T_985e5_row18_col11, #T_985e5_row18_col14, #T_985e5_row19_col11, #T_985e5_row19_col14 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col4, #T_985e5_row3_col4, #T_985e5_row12_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_985e5_row0_col5, #T_985e5_row1_col4, #T_985e5_row3_col5, #T_985e5_row6_col5, #T_985e5_row8_col4, #T_985e5_row13_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_985e5_row0_col6, #T_985e5_row0_col11, #T_985e5_row0_col12, #T_985e5_row0_col14, #T_985e5_row1_col8, #T_985e5_row1_col12, #T_985e5_row1_col14, #T_985e5_row1_col15, #T_985e5_row2_col0, #T_985e5_row3_col8, #T_985e5_row3_col11, #T_985e5_row3_col15, #T_985e5_row3_col17, #T_985e5_row5_col0, #T_985e5_row5_col15, #T_985e5_row7_col3, #T_985e5_row7_col12, #T_985e5_row8_col0, #T_985e5_row10_col15, #T_985e5_row11_col3, #T_985e5_row11_col15, #T_985e5_row12_col0, #T_985e5_row12_col15, #T_985e5_row13_col15, #T_985e5_row14_col8, #T_985e5_row14_col15, #T_985e5_row16_col15, #T_985e5_row17_col0, #T_985e5_row17_col15, #T_985e5_row18_col15, #T_985e5_row19_col15 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col7, #T_985e5_row11_col7, #T_985e5_row13_col7, #T_985e5_row13_col9, #T_985e5_row14_col7, #T_985e5_row15_col7, #T_985e5_row16_col7, #T_985e5_row18_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col13, #T_985e5_row2_col17, #T_985e5_row3_col1, #T_985e5_row6_col10, #T_985e5_row9_col17, #T_985e5_row12_col1, #T_985e5_row15_col1, #T_985e5_row16_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col15, #T_985e5_row1_col11, #T_985e5_row2_col3, #T_985e5_row2_col6, #T_985e5_row2_col18, #T_985e5_row3_col12, #T_985e5_row4_col3, #T_985e5_row4_col15, #T_985e5_row5_col8, #T_985e5_row6_col18, #T_985e5_row8_col17, #T_985e5_row8_col18, #T_985e5_row10_col12, #T_985e5_row11_col12, #T_985e5_row13_col12, #T_985e5_row14_col12, #T_985e5_row15_col0, #T_985e5_row15_col6, #T_985e5_row15_col12, #T_985e5_row16_col12, #T_985e5_row17_col3, #T_985e5_row17_col12, #T_985e5_row18_col12, #T_985e5_row19_col0, #T_985e5_row19_col12 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col16, #T_985e5_row0_col19, #T_985e5_row3_col19 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col17, #T_985e5_row2_col10, #T_985e5_row2_col15, #T_985e5_row3_col6, #T_985e5_row5_col3, #T_985e5_row5_col6, #T_985e5_row6_col1, #T_985e5_row6_col3, #T_985e5_row6_col17, #T_985e5_row8_col1, #T_985e5_row8_col6, #T_985e5_row8_col10, #T_985e5_row9_col10, #T_985e5_row10_col1, #T_985e5_row10_col6, #T_985e5_row13_col1, #T_985e5_row16_col8, #T_985e5_row17_col1, #T_985e5_row18_col1, #T_985e5_row19_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_985e5_row0_col18, #T_985e5_row1_col18, #T_985e5_row4_col0, #T_985e5_row4_col5, #T_985e5_row4_col6, #T_985e5_row4_col11, #T_985e5_row4_col12, #T_985e5_row4_col13, #T_985e5_row4_col16, #T_985e5_row4_col19, #T_985e5_row5_col2, #T_985e5_row5_col4, #T_985e5_row5_col9, #T_985e5_row5_col10, #T_985e5_row5_col14, #T_985e5_row5_col17, #T_985e5_row5_col18, #T_985e5_row6_col0, #T_985e5_row6_col15, #T_985e5_row7_col6, #T_985e5_row7_col9, #T_985e5_row9_col0, #T_985e5_row9_col1, #T_985e5_row9_col3, #T_985e5_row9_col6, #T_985e5_row9_col7, #T_985e5_row9_col12, #T_985e5_row10_col0, #T_985e5_row11_col0, #T_985e5_row17_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col2, #T_985e5_row3_col2, #T_985e5_row4_col17, #T_985e5_row6_col19 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col3, #T_985e5_row1_col10, #T_985e5_row1_col17, #T_985e5_row3_col10, #T_985e5_row6_col12, #T_985e5_row7_col17, #T_985e5_row8_col3, #T_985e5_row8_col11, #T_985e5_row9_col11, #T_985e5_row9_col14, #T_985e5_row9_col15, #T_985e5_row10_col3, #T_985e5_row10_col17, #T_985e5_row11_col6, #T_985e5_row11_col10, #T_985e5_row11_col17, #T_985e5_row12_col8, #T_985e5_row12_col10, #T_985e5_row12_col17, #T_985e5_row13_col3, #T_985e5_row13_col6, #T_985e5_row13_col10, #T_985e5_row13_col17, #T_985e5_row14_col1, #T_985e5_row14_col10, #T_985e5_row14_col17, #T_985e5_row15_col3, #T_985e5_row15_col10, #T_985e5_row15_col17, #T_985e5_row16_col0, #T_985e5_row16_col10, #T_985e5_row16_col17, #T_985e5_row17_col6, #T_985e5_row17_col10, #T_985e5_row18_col3, #T_985e5_row18_col6, #T_985e5_row18_col10, #T_985e5_row18_col17, #T_985e5_row19_col3, #T_985e5_row19_col10, #T_985e5_row19_col17 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_985e5_row1_col7, #T_985e5_row8_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col16, #T_985e5_row3_col16, #T_985e5_row10_col16, #T_985e5_row11_col16, #T_985e5_row12_col16, #T_985e5_row13_col16, #T_985e5_row14_col16, #T_985e5_row15_col16, #T_985e5_row17_col16, #T_985e5_row18_col16, #T_985e5_row19_col16 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_985e5_row1_col19, #T_985e5_row6_col2, #T_985e5_row7_col19, #T_985e5_row8_col16, #T_985e5_row16_col2, #T_985e5_row19_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_985e5_row2_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_985e5_row2_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_985e5_row2_col7, #T_985e5_row10_col7, #T_985e5_row15_col9, #T_985e5_row17_col9, #T_985e5_row19_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_985e5_row2_col8, #T_985e5_row2_col12, #T_985e5_row3_col0, #T_985e5_row3_col18, #T_985e5_row4_col18, #T_985e5_row5_col12, #T_985e5_row7_col0, #T_985e5_row7_col8, #T_985e5_row7_col15, #T_985e5_row7_col18, #T_985e5_row8_col15, #T_985e5_row10_col18, #T_985e5_row11_col18, #T_985e5_row12_col18, #T_985e5_row13_col0, #T_985e5_row13_col18, #T_985e5_row14_col0, #T_985e5_row14_col18, #T_985e5_row15_col8, #T_985e5_row15_col18, #T_985e5_row16_col18, #T_985e5_row17_col18, #T_985e5_row18_col0, #T_985e5_row19_col18 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_985e5_row2_col9 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_985e5_row2_col13, #T_985e5_row3_col13, #T_985e5_row5_col1, #T_985e5_row6_col1

# %% [markdown]
# ***
# ### We can see here that there is a strong positive correlation between the Age and the churn, which means that when the age is larger, the possibility of churn is larger, which can tell us that as a person gets older it's more probable that they will chur.
#
# ### Also we can see a strong negative correlation this time between the (Number of Products and Is active member) with the exited probability, which tells us that when a person is more active the probability of them exiting is low, also when a client has more products in the bank, they are less probable to churn.
#
# ### From this we can see that these two variables are strongly important in the decision of the probability of a customer churn.
# ***

# %% [markdown]
# # **2. Data preprocessing**

# %% [markdown]
# ***
# ### First we will deal with the categorical data, here we have five categorical variables:
# * Geography
# * Gender
# * Tenure
# * HasCrCard
# * IsActiveMember
#
# ### The target value is practically categorical.
# ***

# %% [markdown]
# ## **2.1. Label encoding for the categorical variables**

# %%
# df_train = df_train.drop("Surname", axis=1)

test_ids = df_test["id"]
# df_test = df_test.drop(["Surname", "id"], axis=1)
df_test = df_test.drop(["id"], axis=1)

# %%
df_test.head()
# Out:
#    CustomerId  CreditScore Geography  Gender   Age  Tenure    Balance  \
# 0    15773898          586    France  Female  23.0       2       0.00
# 1    15782418          683    France  Female  46.0       2       0.00
# 2    15807120          656    France  Female  34.0       7       0.00
# 3    15808905          681    France    Male  36.0       8       0.00
# 4    15607314          752   Germany    Male  38.0      10  121263.62
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_1  \
# 0              2        0.0             1.0  ...      -0.024378
# 1              1        1.0             0.0  ...      -0.023024
# 2              2        1.0             0.0  ...      -0.019073
# 3              1        1.0             0.0  ...      -0.026028
# 4              1        1.0             0.0  ...      -0.021392
#
#    Surname_PCA_2  Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  \
# 0      -0.024712      -0.043126      -0.014381      -0.042120      -0.020026
# 1      -0.014986      -0.021009      -0.002549      -0.009497      -0.006892
# 2      -0.012028      -0.016316      -0.001886      -0.006330      -0.005088
# 3      -0.017573      -0.025592      -0.004324      -0.012943      -0.007183
# 4      -0.014021      -0.019666      -0.003642      -0.015915       0.014490
#
#    Surname_PCA_7  Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.029701       0.002547      -0.062395       -0.009487
# 1      -0.002347      -0.010468      -0.010055        0.005830
# 2      -0.001633      -0.007440      -0.006661        0.003955
# 3      -0.001906      -0.014068      -0.011831        0.004597
# 4      -0.000440      -0.004024      -0.005569        0.003169
#
# [5 rows x 21 columns]

# %%
df_train.head()
# Out:
#    CustomerId  CreditScore Geography Gender   Age  Tenure    Balance  \
# 0    15674932          668    France   Male  33.0       3       0.00
# 1    15749177          627    France   Male  33.0       1       0.00
# 2    15694510          678    France   Male  40.0      10       0.00
# 3    15741417          581    France   Male  34.0       2  148882.54
# 4    15766172          716     Spain   Male  33.0       5       0.00
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_1  \
# 0              2        1.0             0.0  ...       0.428586
# 1              2        1.0             1.0  ...       0.105779
# 2              2        1.0             0.0  ...      -0.035401
# 3              1        1.0             1.0  ...      -0.035992
# 4              2        1.0             1.0  ...      -0.028723
#
#    Surname_PCA_2  Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  \
# 0       0.055080       0.043749       0.003175       0.004882       0.005035
# 1       0.001855      -0.007653      -0.004979      -0.016212      -0.029939
# 2      -0.029099      -0.037264       0.004022      -0.051364      -0.060943
# 3      -0.029410      -0.042073      -0.011395      -0.042140      -0.056974
# 4      -0.032024      -0.026693      -0.016294      -0.037567      -0.046233
#
#    Surname_PCA_7  Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.017626       0.007490       0.011937        0.009756
# 1       0.052591       0.027870       0.013041        0.005447
# 2      -0.041192      -0.099771      -0.098887        0.025862
# 3      -0.026287      -0.114804      -0.092143        0.159736
# 4      -0.046991      -0.056859      -0.100200       -0.182821
#
# [5 rows x 22 columns]

# %%
enc = LabelEncoder()

categorical_features = ["Geography", "Gender", "Tenure", "HasCrCard", "IsActiveMember"]

for cat_feat in categorical_features:
    df_train[cat_feat] = enc.fit_transform(df_train[cat_feat])
    df_test[cat_feat] = enc.transform(df_test[cat_feat])

# %%
df_train.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0    15674932          668          0       1  33.0       3       0.00
# 1    15749177          627          0       1  33.0       1       0.00
# 2    15694510          678          0       1  40.0      10       0.00
# 3    15741417          581          0       1  34.0       2  148882.54
# 4    15766172          716          2       1  33.0       5       0.00
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_1  \
# 0              2          1               0  ...       0.428586
# 1              2          1               1  ...       0.105779
# 2              2          1               0  ...      -0.035401
# 3              1          1               1  ...      -0.035992
# 4              2          1               1  ...      -0.028723
#
#    Surname_PCA_2  Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  \
# 0       0.055080       0.043749       0.003175       0.004882       0.005035
# 1       0.001855      -0.007653      -0.004979      -0.016212      -0.029939
# 2      -0.029099      -0.037264       0.004022      -0.051364      -0.060943
# 3      -0.029410      -0.042073      -0.011395      -0.042140      -0.056974
# 4      -0.032024      -0.026693      -0.016294      -0.037567      -0.046233
#
#    Surname_PCA_7  Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.017626       0.007490       0.011937        0.009756
# 1       0.052591       0.027870       0.013041        0.005447
# 2      -0.041192      -0.099771      -0.098887        0.025862
# 3      -0.026287      -0.114804      -0.092143        0.159736
# 4      -0.046991      -0.056859      -0.100200       -0.182821
#
# [5 rows x 22 columns]

# %%
df_test.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0    15773898          586          0       0  23.0       2       0.00
# 1    15782418          683          0       0  46.0       2       0.00
# 2    15807120          656          0       0  34.0       7       0.00
# 3    15808905          681          0       1  36.0       8       0.00
# 4    15607314          752          1       1  38.0      10  121263.62
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_1  \
# 0              2          0               1  ...      -0.024378
# 1              1          1               0  ...      -0.023024
# 2              2          1               0  ...      -0.019073
# 3              1          1               0  ...      -0.026028
# 4              1          1               0  ...      -0.021392
#
#    Surname_PCA_2  Surname_PCA_3  Surname_PCA_4  Surname_PCA_5  Surname_PCA_6  \
# 0      -0.024712      -0.043126      -0.014381      -0.042120      -0.020026
# 1      -0.014986      -0.021009      -0.002549      -0.009497      -0.006892
# 2      -0.012028      -0.016316      -0.001886      -0.006330      -0.005088
# 3      -0.017573      -0.025592      -0.004324      -0.012943      -0.007183
# 4      -0.014021      -0.019666      -0.003642      -0.015915       0.014490
#
#    Surname_PCA_7  Surname_PCA_8  Surname_PCA_9  Surname_PCA_10
# 0       0.029701       0.002547      -0.062395       -0.009487
# 1      -0.002347      -0.010468      -0.010055        0.005830
# 2      -0.001633      -0.007440      -0.006661        0.003955
# 3      -0.001906      -0.014068      -0.011831        0.004597
# 4      -0.000440      -0.004024      -0.005569        0.003169
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Now we will wrok on the numerical data, in this first version we will just scale the numerical data using a simple scaler, why do we need to scale it, well, as you can see, we can have values for a variable like 10000 and another value for another varibale like 0.38, usually the model will understand that the variable with 10000 is much more important than the variable with value 0.38, which is not necessary the case, so we need to center (or scale) the values to the same scale so that the proportion between them stays same but the huge gap is reduced around a fixed value.
#
# ### **UDAPTE: i did this because i was expecting that i will use a neural network, but it turned out i will not so scaling is not necessary here.**

# %% [markdown]
# ## **2.2. Adding more features**

# %%
# by https://www.kaggle.com/code/chinmayadatt/notebook-analysing-bank-churn-dataset
def add_new_features(df):
    df['Geo_Gender'] = df['Geography'] + df['Gender'] + 10
    df['AgeGroup'] = df['Age'] // 10 * 10
    df['IsSenior'] = df['Age'].apply(lambda x: 1 if x >= 60 else 0)
    df['QualityOfBalance'] = pd.cut(df['Balance'], bins=[-1,100,1000,10000,50000,1000000], labels=['VeryLow', 'Low', 'Medium','High','Highest'])
    df['QualityOfBalance'].replace(['VeryLow', 'Low', 'Medium','High','Highest'],[0,1,2,3,4], inplace=True)
    df['Balance_to_Salary_Ratio'] = df['Balance'] / df['EstimatedSalary']
    df['CreditScoreTier'] = pd.cut(df['CreditScore'], bins=[0, 650, 750, 850], labels=['Low', 'Medium', 'High'])
    df['CreditScoreTier'].replace(['Low', 'Medium', 'High'],[0, 1, 2], inplace=True)
    df['IsActive_by_CreditCard'] = df['HasCrCard'] * df['IsActiveMember']
    df['Products_Per_Tenure'] =  df['Tenure'] / df['NumOfProducts']
    df['Customer_Status'] = df['Tenure'].apply(lambda x:0 if x < 2 else 1)
    return df

# %%
df_train = add_new_features(df_train)
df_test  = add_new_features(df_test)

# %%
df_train.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0    15674932          668          0       1  33.0       3       0.00
# 1    15749177          627          0       1  33.0       1       0.00
# 2    15694510          678          0       1  40.0      10       0.00
# 3    15741417          581          0       1  34.0       2  148882.54
# 4    15766172          716          2       1  33.0       5       0.00
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_10  Geo_Gender  \
# 0              2          1               0  ...        0.009756          11
# 1              2          1               1  ...        0.005447          11
# 2              2          1               0  ...        0.025862          11
# 3              1          1               1  ...        0.159736          11
# 4              2          1               1  ...       -0.182821          13
#
#    AgeGroup  IsSenior  QualityOfBalance  Balance_to_Salary_Ratio  \
# 0      30.0         0                 0                 0.000000
# 1      30.0         0                 0                 0.000000
# 2      40.0         0                 0                 0.000000
# 3      30.0         0                 4                 1.760655
# 4      30.0         0                 0                 0.000000
#
#    CreditScoreTier  IsActive_by_CreditCard  Products_Per_Tenure  \
# 0                1                       0                  1.5
# 1                0                       1                  0.5
# 2                1                       0                  5.0
# 3                0                       1                  2.0
# 4                1                       1                  2.5
#
#    Customer_Status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
#
# [5 rows x 31 columns]

# %%
df_train = df_train.astype({
    'QualityOfBalance': int,
    'CreditScoreTier': int
})
df_test = df_test.astype({
    'QualityOfBalance': int,
    'CreditScoreTier': int
})

# %%
df_train.describe()
# Out:
#          CustomerId    CreditScore      Geography         Gender  \
# count  1.750300e+05  175030.000000  175030.000000  175030.000000
# mean   1.569194e+07     656.114506       0.654134       0.563355
# std    7.142844e+04      81.148932       0.817515       0.495971
# min    1.556570e+07     350.000000       0.000000       0.000000
# 25%    1.563288e+07     597.000000       0.000000       0.000000
# 50%    1.569017e+07     659.000000       0.000000       1.000000
# 75%    1.575666e+07     710.000000       1.000000       1.000000
# max    1.581569e+07     850.000000       2.000000       1.000000
#
#                  Age         Tenure        Balance  NumOfProducts  \
# count  175030.000000  175030.000000  175030.000000  175030.000000
# mean       38.171301       5.019951   56677.296954       1.553071
# std         8.969551       2.811144   62982.318837       0.549211
# min        18.000000       0.000000       0.000000       1.000000
# 25%        32.000000       3.000000       0.000000       1.000000
# 50%        37.000000       5.000000       0.000000       2.000000
# 75%        42.000000       7.000000  120727.970000       2.000000
# max        92.000000      10.000000  250898.090000       4.000000
#
#            HasCrCard  IsActiveMember  ...  Surname_PCA_10     Geo_Gender  \
# count  175030.000000   175030.000000  ...    1.750300e+05  175030.000000
# mean        0.751186        0.498749  ...    9.824107e-18      11.217488
# std         0.432327        0.500000  ...    9.716894e-02       0.951383
# min         0.000000        0.000000  ...   -4.242308e-01      10.000000
# 25%         1.000000        0.000000  ...   -1.521507e-02      11.000000
# 50%         1.000000        0.000000  ...    3.888489e-03      11.000000
# 75%         1.000000        1.000000  ...    7.552492e-03      12.000000
# max         1.000000        1.000000  ...    7.315436e-01      13.000000
#
#             AgeGroup       IsSenior  QualityOfBalance  \
# count  175030.000000  175030.000000     175030.000000
# mean       33.619494       0.030098          1.866966
# std         9.457993       0.170857          1.994369
# min        10.000000       0.000000          0.000000
# 25%        30.000000       0.000000          0.000000
# 50%        30.000000       0.000000          0.000000
# 75%        40.000000       0.000000          4.000000
# max        90.000000       1.000000          4.000000
#
#        Balance_to_Salary_Ratio  CreditScoreTier  IsActive_by_CreditCard  \
# count            175030.000000    175030.000000           175030.000000
# mean                  2.202492         0.654059                0.370182
# std                  92.678906         0.673838                0.482855
# min                   0.000000         0.000000                0.000000
# 25%                   0.000000         0.000000                0.000000
# 50%                   0.000000         1.000000                0.000000
# 75%                   1.000001         1.000000                1.000000
# max               12863.796200         2.000000                1.000000
#
#        Products_Per_Tenure  Customer_Status
# count        175030.000000    175030.000000
# mean              3.667330         0.867366
# std               2.523826         0.339180
# min               0.000000         0.000000
# 25%               1.666667         1.000000
# 50%               3.000000         1.000000
# 75%               5.000000         1.000000
# max              10.000000         1.000000
#
# [8 rows x 31 columns]

# %%
# numeric_data      = df_train.drop(["Geography", "Gender", "Tenure", "HasCrCard", "IsActiveMember", "Geo_Gender", "IsSenior", "QualityOfBalance", "CreditScoreTier", "IsActive_by_CreditCard", "Products_Per_Tenure", "Customer_Status", "Exited"], axis=1)
# numeric_data_test = df_test.drop(["Geography", "Gender", "Tenure", "HasCrCard", "IsActiveMember", "Geo_Gender", "IsSenior", "QualityOfBalance", "CreditScoreTier", "IsActive_by_CreditCard", "Products_Per_Tenure", "Customer_Status"], axis=1)

# numeric_data      = numeric_data.drop("CustomerId", axis=1)
# numeric_data_test = numeric_data_test.drop("CustomerId", axis=1)
# numeric_data.head()

# %%
# numeric_data.head()

# %%
# numeric_data_test.head()

# %%
# scaler = StandardScaler()

# scaled_numerical_data_train = scaler.fit_transform(numeric_data)
# scaled_numerical_data_test  = scaler.transform(numeric_data_test)

# %%
# scaled_numerical_data_train[0]

# %%
# pca_columns = [f'Surname_PCA_{i+1}' for i in range(10)]
# features = ["CreditScore", "Age", "Balance", "NumOfProducts", "EstimatedSalary"]
# for i in pca_columns:
#     features.append(i)

# for i, feat in enumerate(features):
#     l = []
    
#     for j in range(len(scaled_numerical_data_train)):
#         l.append(scaled_numerical_data_train[j][i])
    
#     df_train[feat] = l
    
#     l = []
    
#     for j in range(len(scaled_numerical_data_test)):
#         l.append(scaled_numerical_data_test[j][i])
    
#     df_test[feat]  = l

# %%
df_train.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0    15674932          668          0       1  33.0       3       0.00
# 1    15749177          627          0       1  33.0       1       0.00
# 2    15694510          678          0       1  40.0      10       0.00
# 3    15741417          581          0       1  34.0       2  148882.54
# 4    15766172          716          2       1  33.0       5       0.00
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_10  Geo_Gender  \
# 0              2          1               0  ...        0.009756          11
# 1              2          1               1  ...        0.005447          11
# 2              2          1               0  ...        0.025862          11
# 3              1          1               1  ...        0.159736          11
# 4              2          1               1  ...       -0.182821          13
#
#    AgeGroup  IsSenior  QualityOfBalance  Balance_to_Salary_Ratio  \
# 0      30.0         0                 0                 0.000000
# 1      30.0         0                 0                 0.000000
# 2      40.0         0                 0                 0.000000
# 3      30.0         0                 4                 1.760655
# 4      30.0         0                 0                 0.000000
#
#    CreditScoreTier  IsActive_by_CreditCard  Products_Per_Tenure  \
# 0                1                       0                  1.5
# 1                0                       1                  0.5
# 2                1                       0                  5.0
# 3                0                       1                  2.0
# 4                1                       1                  2.5
#
#    Customer_Status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
#
# [5 rows x 31 columns]

# %%
df_test.head()
# Out:
#    CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0    15773898          586          0       0  23.0       2       0.00
# 1    15782418          683          0       0  46.0       2       0.00
# 2    15807120          656          0       0  34.0       7       0.00
# 3    15808905          681          0       1  36.0       8       0.00
# 4    15607314          752          1       1  38.0      10  121263.62
#
#    NumOfProducts  HasCrCard  IsActiveMember  ...  Surname_PCA_10  Geo_Gender  \
# 0              2          0               1  ...       -0.009487          10
# 1              1          1               0  ...        0.005830          10
# 2              2          1               0  ...        0.003955          10
# 3              1          1               0  ...        0.004597          11
# 4              1          1               0  ...        0.003169          12
#
#    AgeGroup  IsSenior  QualityOfBalance  Balance_to_Salary_Ratio  \
# 0      20.0         0                 0                 0.000000
# 1      40.0         0                 0                 0.000000
# 2      30.0         0                 0                 0.000000
# 3      30.0         0                 0                 0.000000
# 4      30.0         0                 4                 0.869703
#
#    CreditScoreTier  IsActive_by_CreditCard  Products_Per_Tenure  \
# 0                0                       0                  1.0
# 1                1                       0                  2.0
# 2                1                       0                  3.5
# 3                1                       0                  8.0
# 4                2                       0                 10.0
#
#    Customer_Status
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
# [5 rows x 30 columns]

# %% [markdown]
# # **3. Modeling**

# %% [markdown]
# ### **Alright, now that our data is ready to go, we need to make the best model to get the best result :)**

# %% [markdown]
# ## **3.1. First we start by spliting the data into train and validation data**

# %%
X = df_train.drop("Exited", axis=1)
y = df_train["Exited"]
X_test = df_test

# %% [markdown]
# ## **3.2. We make the models**

# %% [markdown]
# ***
# ### We will go with the following models, then use a voting classifier:
#
# * LightGBM
# * XGboost
# * CatBoost
# ***

# %%
lgbm = LGBMClassifier(**{  'objective'           : 'binary',
                           'boosting_type'       : 'gbdt',
                           'metric'              : "auc",
                           'random_state'        : 42,
                           'colsample_bytree'    : 0.56,
                           'subsample'           : 0.35,
                           'learning_rate'       : 0.05,
                           'max_depth'           : 8,
                           'n_estimators'        : 1000,
                           'num_leaves'          : 140,
                           'reg_alpha'           : 0.14,
                           'reg_lambda'          : 0.85,
                           'verbosity'           : -1, 
                          })
xgb  = XGBClassifier(**{  'objective'             : 'binary:logistic',
                          'eval_metric'           : "auc",
                          'random_state'          : 42,
                          'colsample_bytree'      : 0.25,
                          'learning_rate'         : 0.07,
                          'max_depth'             : 8,
                          'n_estimators'          : 800,                         
                          'reg_alpha'             : 0.09,
                          'reg_lambda'            : 0.70,
                          'min_child_weight'      : 22,
                          'verbosity'             : 0,
                         })
cat  = CatBoostClassifier(**{
                         'iterations'            : 10000,
                         'objective'             : 'Logloss',
                         'eval_metric'           : "AUC",
                         'early_stopping_rounds' : 1000,
                         'bagging_temperature'   : 0.1,
                         'colsample_bylevel'     : 0.88,
                         'iterations'            : 1000,
                         'learning_rate'         : 0.065,
                         'max_depth'             : 7,
                         'l2_leaf_reg'           : 1,
                         'min_data_in_leaf'      : 25,
                         'random_strength'       : 0.1, 
                         'max_bin'               : 100,
                         'verbose'               : 0,
                        })

vote = VotingClassifier(estimators=[('lgbm', lgbm), ('xgb', xgb), ('cat', cat)], voting='soft', weights=[2, 1, 1])

# Initialize an empty array to hold the submission predictions
submission_predictions = []

kf = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=42)

# save aucs
aucs = []
ind = 1

for train_index, test_index in kf.split(X, y):
    print(f"============== Working on fold #{ind} ================")
    X_train_kf, X_val_kf = X.iloc[train_index], X.iloc[test_index]
    y_train_kf, y_val_kf = y.iloc[train_index], y.iloc[test_index]

    print()
    print("               Fitting the voting model...              ")
    # Fit the model
    vote.fit(X_train_kf, y_train_kf)

    print()
    print("            Predicting on the validation data           ")
    # Predict probabilities for validation set
    y_pred_val = vote.predict_proba(X_val_kf)[:, 1]

    # Calculate AUC for validation set
    auc_val = roc_auc_score(y_val_kf, y_pred_val)
    print()
    print(f"           Validation ROC AUC Score: {auc_val}        ")
    
    aucs.append(auc_val)

    print()
    print("             Predicting on submission data...")
    # Predict probabilities for test set (df_test)
    y_pred_test = vote.predict_proba(X_test)[:, 1]
    submission_predictions.append(y_pred_test)
    
    print()
    print(f"                 Fold #{ind} finished !                ")
    
    ind+=1
# Out:
# ============== Working on fold #1 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8921600505902758
#
#              Predicting on submission data...
#
#                  Fold #1 finished !
# ============== Working on fold #2 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8903775512951301
#
#              Predicting on submission data...
#
#                  Fold #2 finished !
# ============== Working on fold #3 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8903175549990797
#
#              Predicting on submission data...
#
#                  Fold #3 finished !
# ============== Working on fold #4 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.890172661747429
#
#              Predicting on submission data...
#
#                  Fold #4 finished !
# ============== Working on fold #5 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8889294902877234
#
#              Predicting on submission data...
#
#                  Fold #5 finished !
# ============== Working on fold #6 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.891865225635565
#
#              Predicting on submission data...
#
#                  Fold #6 finished !
# ============== Working on fold #7 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8930037052712716
#
#              Predicting on submission data...
#
#                  Fold #7 finished !
# ============== Working on fold #8 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8921911757305488
#
#              Predicting on submission data...
#
#                  Fold #8 finished !
# ============== Working on fold #9 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8855469755522718
#
#              Predicting on submission data...
#
#                  Fold #9 finished !
# ============== Working on fold #10 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8910010703954672
#
#              Predicting on submission data...
#
#                  Fold #10 finished !
# ============== Working on fold #11 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8877409589345233
#
#              Predicting on submission data...
#
#                  Fold #11 finished !
# ============== Working on fold #12 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8913853196236509
#
#              Predicting on submission data...
#
#                  Fold #12 finished !
# ============== Working on fold #13 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8885735989328143
#
#              Predicting on submission data...
#
#                  Fold #13 finished !
# ============== Working on fold #14 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8907901776210198
#
#              Predicting on submission data...
#
#                  Fold #14 finished !
# ============== Working on fold #15 ================
#
#                Fitting the voting model...
#
#             Predicting on the validation data
#
#            Validation ROC AUC Score: 0.8930060777957224
#
#              Predicting on submission data...
#
#                  Fold #15 finished !

# %%
print(f"Average ROC AUC Score: {sum(aucs) / len(aucs)}")

# Average predictions from different folds
avg_submission = pd.DataFrame(submission_predictions).mean(axis=0)

submission["Exited"] = avg_submission

# Save submission to CSV
submission.to_csv("submission.csv", index=False)

submission.head()
# Out:
# Average ROC AUC Score: 0.8904707729608329
#        id    Exited
# 0  165034  0.024201
# 1  165035  0.884933
# 2  165036  0.020870
# 3  165037  0.183358
# 4  165038  0.294096

# %% [markdown]
# ## **Cool, I will be trying to improve it, and I will keep changing the public notebook to help everyone understand as much as I can. Make sure to upvote if you find this helpful, Thanks :P**
